# %%
import os
os.chdir('/mnt/newssd/lerobot')
# !ls

# %%
import lerobot
print(lerobot.available_datasets)

# %%
# !pip install humanize
# !sudo apt-get update && sudo apt-get install tree

# %%
#Download aloha static datasets
from huggingface_hub import snapshot_download
import os

# Target directory
base_output_dir = "/mnt/newssd/lerobot/lerobot/datasets"
os.makedirs(base_output_dir, exist_ok=True)

# Dataset list
dataset_names = [
    "aloha_static_candy",
    "aloha_static_coffee",
    "aloha_static_coffee_new",
    "aloha_static_cups_open",
    "aloha_static_fork_pick_up",
    "aloha_static_pingpong_test",
    "aloha_static_pro_pencil",
    "aloha_static_screw_driver",
    "aloha_static_tape",
    "aloha_static_thread_velcro",
    "aloha_static_towel",
    "aloha_static_vinh_cup",
    "aloha_static_vinh_cup_left",
    "aloha_static_ziploc_slide"
]

# Loop through each dataset and download
for name in dataset_names:
    repo_id = f"lerobot/{name}"
    local_dir = os.path.join(base_output_dir, name)
    print(f"📥 Downloading {repo_id} to {local_dir}...")
    try:
        snapshot_download(repo_id=repo_id, repo_type="dataset", local_dir=local_dir, local_dir_use_symlinks=False)
        print(f"✅ Done: {name}")
    except Exception as e:
        print(f"❌ Failed to download {name}: {e}")

# %%
snapshot_download(
    repo_id="Qipei/Task_PicupBrick_50fps_with_mountingpoints",
    repo_type="dataset",
    local_dir="/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints",
)

# %%
import pandas as pd
import glob

files = sorted(glob.glob('/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotraining_test/data/chunk-000/*.parquet'))
for i, f in enumerate(files[:50]):  # 只对前50集补列
    df = pd.read_parquet(f)
    if 'next.done' not in df.columns:
        df['next.done'] = False
    df.to_parquet(f, index=False)

# %%
import pandas as pd
import numpy as np
import glob
import os

# 你的parquet文件路径
parquet_dir = "/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotraining_test/data/chunk-000/"
all_files = sorted(glob.glob(os.path.join(parquet_dir, "episode_*.parquet")))

# 取前50和后50
first_50 = all_files[:50]
last_50 = all_files[-50:]

def analyze(files, name):
    print(f"== {name} ==")
    columns_set = set()
    dtype_dict = {}
    action_shapes = []
    state_shapes = []
    action_means = []
    state_means = []
    for f in files:
        df = pd.read_parquet(f)
        columns_set.update(df.columns)
        for col in df.columns:
            dtype_dict.setdefault(col, set()).add(df[col].dtype)
        # 统计 action/state shape
        if 'action' in df.columns:
            action_shapes += [np.array(x).shape for x in df['action']]
            # 也可以统计均值
            action_means.append(np.mean([np.mean(x) for x in df['action'] if isinstance(x, (list, np.ndarray))]))
        if 'observation.state' in df.columns:
            state_shapes += [np.array(x).shape for x in df['observation.state']]
            state_means.append(np.mean([np.mean(x) for x in df['observation.state'] if isinstance(x, (list, np.ndarray))]))
    print("字段：", columns_set)
    print("各字段dtype：", {k: list(v) for k, v in dtype_dict.items()})
    if action_shapes:
        print("action shape统计：", set(action_shapes))
        print("action 均值均值：", np.mean(action_means) if action_means else "N/A")
    if state_shapes:
        print("observation.state shape统计：", set(state_shapes))
        print("state 均值均值：", np.mean(state_means) if state_means else "N/A")
    print()

analyze(first_50, "前50集")
analyze(last_50, "后50集")

# %%
# !python lerobot/scripts/train.py \
  --config_path='/mnt/newssd/lerobot/outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotraining/checkpoints/last/pretrained_model/train_config.json' \
  --resume=true \
  --steps=400000

# %%
import os
import pandas as pd

base_dir = "/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_aug900_with_static/data"

for chunk in os.listdir(base_dir):
    chunk_path = os.path.join(base_dir, chunk)
    if not os.path.isdir(chunk_path):
        continue
    for file in os.listdir(chunk_path):
        if file.endswith(".parquet"):
            file_path = os.path.join(chunk_path, file)
            df = pd.read_parquet(file_path)
            cols_to_drop = []
            for col in ["next.done", "observation.effort"]:
                if col in df.columns:
                    cols_to_drop.append(col)
            if cols_to_drop:
                print(f"Fixing {file_path} (removing {cols_to_drop})")
                df = df.drop(columns=cols_to_drop)
                df.to_parquet(file_path, index=False)

# %%
import os
import pandas as pd

# Directory containing all chunks (change as needed)
base_dir = "/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_aug900_with_static/data"
DESIRED_LEN = 20

# %%
#remove the no need column
import os
import pandas as pd

dir_path = '/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain/data/chunk-000'

for fname in os.listdir(dir_path):
    if fname.endswith('.parquet'):
        fpath = os.path.join(dir_path, fname)
        df = pd.read_parquet(fpath)
        if 'observation.effort' in df.columns:
            print('Dropping observation.effort from:', fname)
            df = df.drop(columns=['observation.effort'])
            df.to_parquet(fpath)
# Out:
# Dropping observation.effort from: episode_000587.parquet
# Dropping observation.effort from: episode_000535.parquet
# Dropping observation.effort from: episode_000265.parquet
# Dropping observation.effort from: episode_000430.parquet
# Dropping observation.effort from: episode_000195.parquet
# Dropping observation.effort from: episode_000173.parquet
# Dropping observation.effort from: episode_000271.parquet
# Dropping observation.effort from: episode_000435.parquet
# Dropping observation.effort from: episode_000486.parquet
# Dropping observation.effort from: episode_000124.parquet
# Dropping observation.effort from: episode_000506.parquet
# Dropping observation.effort from: episode_000406.parquet
# Dropping observation.effort from: episode_000494.parquet
# Dropping observation.effort from: episode_000132.parquet
# Dropping observation.effort from: episode_000321.parquet
# Dropping observation.effort from: episode_000442.parquet
# Dropping observation.effort from: episode_000543.parquet
# Dropping observation.effort from: episode_000162.parquet
# Dropping observation.effort from: episode_000156.parquet
# Dropping observation.effort from: episode_000125.parquet
# Dropping observation.effort from: episode_000304.parquet
# Dropping observation.effort from: episode_000615.parquet
# Dropping observation.effort from: episode_000483.parquet
# Dropping observation.effort from: episode_000541.parquet
# Dropping observation.effort from: episode_000120.parquet
# Dropping observation.effort from: episode_000518.parquet
# Dropping observation.effort from: episode_000618.parquet
# Dropping observation.effort from: episode_000326.parquet
# Dropping observation.effort from: episode_000613.parquet
# Dropping observation.effort from: episode_000490.parquet
# Dropping observation.effort from: episode_000452.parquet
# Dropping observation.effort from: episode_000585.parquet
# Dropping observation.effort from: episode_000544.parquet
# Dropping observation.effort from: episode_000509.parquet
# Dropping observation.effort from: episode_000559.parquet
# Dropping observation.effort from: episode_000284.parquet
# Dropping observation.effort from: episode_000498.parquet
# Dropping observation.effort from: episode_000524.parquet
# Dropping observation.effort from: episode_000438.parquet
# Dropping observation.effort from: episode_000274.parquet
# Dropping observation.effort from: episode_000420.parquet
# Dropping observation.effort from: episode_000469.parquet
# Dropping observation.effort from: episode_000196.parquet
# Dropping observation.effort from: episode_000182.parquet
# Dropping observation.effort from: episode_000464.parquet
# Dropping observation.effort from: episode_000481.parquet
# Dropping observation.effort from: episode_000260.parquet
# Dropping observation.effort from: episode_000269.parquet
# Dropping observation.effort from: episode_000516.parquet
# Dropping observation.effort from: episode_000192.parquet
# Dropping observation.effort from: episode_000448.parquet
# Dropping observation.effort from: episode_000522.parquet
# Dropping observation.effort from: episode_000259.parquet
# Dropping observation.effort from: episode_000266.parquet
# Dropping observation.effort from: episode_000163.parquet
# Dropping observation.effort from: episode_000286.parquet
# Dropping observation.effort from: episode_000492.parquet
# Dropping observation.effort from: episode_000306.parquet
# Dropping observation.effort from: episode_000465.parquet
# Dropping observation.effort from: episode_000443.parquet
# Dropping observation.effort from: episode_000289.parquet
# Dropping observation.effort from: episode_000396.parquet
# Dropping observation.effort from: episode_000322.parquet
# Dropping observation.effort from: episode_000433.parquet
# Dropping observation.effort from: episode_000475.parquet
# Dropping observation.effort from: episode_000328.parquet
# Dropping observation.effort from: episode_000478.parquet
# Dropping observation.effort from: episode_000311.parquet
# Dropping observation.effort from: episode_000409.parquet
# Dropping observation.effort from: episode_000597.parquet
# Dropping observation.effort from: episode_000188.parquet
# Dropping observation.effort from: episode_000186.parquet
# Dropping observation.effort from: episode_000579.parquet
# Dropping observation.effort from: episode_000427.parquet
# Dropping observation.effort from: episode_000189.parquet
# Dropping observation.effort from: episode_000596.parquet
# Dropping observation.effort from: episode_000288.parquet
# Dropping observation.effort from: episode_000584.parquet
# Dropping observation.effort from: episode_000386.parquet
# Dropping observation.effort from: episode_000109.parquet
# Dropping observation.effort from: episode_000154.parquet
# Dropping observation.effort from: episode_000314.parquet
# Dropping observation.effort from: episode_000500.parquet
# Dropping observation.effort from: episode_000157.parquet
# Dropping observation.effort from: episode_000445.parquet
# Dropping observation.effort from: episode_000388.parquet
# Dropping observation.effort from: episode_000573.parquet
# Dropping observation.effort from: episode_000634.parquet
# Dropping observation.effort from: episode_000262.parquet
# Dropping observation.effort from: episode_000102.parquet
# Dropping observation.effort from: episode_000118.parquet
# Dropping observation.effort from: episode_000470.parquet
# Dropping observation.effort from: episode_000136.parquet
# Dropping observation.effort from: episode_000100.parquet
# Dropping observation.effort from: episode_000267.parquet
# Dropping observation.effort from: episode_000472.parquet
# Dropping observation.effort from: episode_000110.parquet
# Dropping observation.effort from: episode_000525.parquet
# Dropping observation.effort from: episode_000178.parquet
# Dropping observation.effort from: episode_000631.parquet
# Dropping observation.effort from: episode_000423.parquet
# Dropping observation.effort from: episode_000547.parquet
# Dropping observation.effort from: episode_000404.parquet
# Dropping observation.effort from: episode_000174.parquet
# Dropping observation.effort from: episode_000334.parquet
# Dropping observation.effort from: episode_000392.parquet
# Dropping observation.effort from: episode_000293.parquet
# Dropping observation.effort from: episode_000133.parquet
# Dropping observation.effort from: episode_000493.parquet
# Dropping observation.effort from: episode_000568.parquet
# Dropping observation.effort from: episode_000523.parquet
# Dropping observation.effort from: episode_000415.parquet
# Dropping observation.effort from: episode_000577.parquet
# Dropping observation.effort from: episode_000128.parquet
# Dropping observation.effort from: episode_000113.parquet
# Dropping observation.effort from: episode_000583.parquet
# Dropping observation.effort from: episode_000313.parquet
# Dropping observation.effort from: episode_000419.parquet
# Dropping observation.effort from: episode_000560.parquet
# Dropping observation.effort from: episode_000581.parquet
# Dropping observation.effort from: episode_000153.parquet
# Dropping observation.effort from: episode_000287.parquet
# Dropping observation.effort from: episode_000177.parquet
# Dropping observation.effort from: episode_000491.parquet
# Dropping observation.effort from: episode_000166.parquet
# Dropping observation.effort from: episode_000603.parquet
# Dropping observation.effort from: episode_000455.parquet
# Dropping observation.effort from: episode_000151.parquet
# Dropping observation.effort from: episode_000385.parquet
# Dropping observation.effort from: episode_000106.parquet
# Dropping observation.effort from: episode_000107.parquet
# Dropping observation.effort from: episode_000180.parquet
# Dropping observation.effort from: episode_000594.parquet
# Dropping observation.effort from: episode_000281.parquet
# Dropping observation.effort from: episode_000421.parquet
# Dropping observation.effort from: episode_000278.parquet
# Dropping observation.effort from: episode_000571.parquet
# Dropping observation.effort from: episode_000169.parquet
# Dropping observation.effort from: episode_000117.parquet
# Dropping observation.effort from: episode_000277.parquet
# Dropping observation.effort from: episode_000601.parquet
# Dropping observation.effort from: episode_000389.parquet
# Dropping observation.effort from: episode_000140.parquet
# Dropping observation.effort from: episode_000264.parquet
# Dropping observation.effort from: episode_000295.parquet
# Dropping observation.effort from: episode_000395.parquet
# Dropping observation.effort from: episode_000161.parquet
# Dropping observation.effort from: episode_000489.parquet
# Dropping observation.effort from: episode_000428.parquet
# Dropping observation.effort from: episode_000630.parquet
# Dropping observation.effort from: episode_000538.parquet
# Dropping observation.effort from: episode_000407.parquet
# Dropping observation.effort from: episode_000496.parquet
# Dropping observation.effort from: episode_000477.parquet
# Dropping observation.effort from: episode_000394.parquet
# Dropping observation.effort from: episode_000600.parquet
# Dropping observation.effort from: episode_000150.parquet
# Dropping observation.effort from: episode_000534.parquet
# Dropping observation.effort from: episode_000572.parquet
# Dropping observation.effort from: episode_000398.parquet
# Dropping observation.effort from: episode_000628.parquet
# Dropping observation.effort from: episode_000439.parquet
# Dropping observation.effort from: episode_000308.parquet
# Dropping observation.effort from: episode_000497.parquet
# Dropping observation.effort from: episode_000279.parquet
# Dropping observation.effort from: episode_000331.parquet
# Dropping observation.effort from: episode_000254.parquet
# Dropping observation.effort from: episode_000164.parquet
# Dropping observation.effort from: episode_000333.parquet
# Dropping observation.effort from: episode_000616.parquet
# Dropping observation.effort from: episode_000112.parquet
# Dropping observation.effort from: episode_000179.parquet
# Dropping observation.effort from: episode_000527.parquet
# Dropping observation.effort from: episode_000608.parquet
# Dropping observation.effort from: episode_000453.parquet
# Dropping observation.effort from: episode_000614.parquet
# Dropping observation.effort from: episode_000303.parquet
# Dropping observation.effort from: episode_000329.parquet
# Dropping observation.effort from: episode_000632.parquet
# Dropping observation.effort from: episode_000330.parquet
# Dropping observation.effort from: episode_000184.parquet
# Dropping observation.effort from: episode_000501.parquet
# Dropping observation.effort from: episode_000619.parquet
# Dropping observation.effort from: episode_000103.parquet
# Dropping observation.effort from: episode_000172.parquet
# Dropping observation.effort from: episode_000138.parquet
# Dropping observation.effort from: episode_000390.parquet
# Dropping observation.effort from: episode_000436.parquet
# Dropping observation.effort from: episode_000609.parquet
# Dropping observation.effort from: episode_000426.parquet
# Dropping observation.effort from: episode_000598.parquet
# Dropping observation.effort from: episode_000451.parquet
# Dropping observation.effort from: episode_000431.parquet
# Dropping observation.effort from: episode_000553.parquet
# Dropping observation.effort from: episode_000485.parquet
# Dropping observation.effort from: episode_000252.parquet
# Dropping observation.effort from: episode_000302.parquet
# Dropping observation.effort from: episode_000432.parquet
# Dropping observation.effort from: episode_000529.parquet
# Dropping observation.effort from: episode_000127.parquet
# Dropping observation.effort from: episode_000108.parquet
# Dropping observation.effort from: episode_000567.parquet
# Dropping observation.effort from: episode_000159.parquet
# Dropping observation.effort from: episode_000519.parquet
# Dropping observation.effort from: episode_000466.parquet
# Dropping observation.effort from: episode_000503.parquet
# Dropping observation.effort from: episode_000387.parquet
# Dropping observation.effort from: episode_000545.parquet
# Dropping observation.effort from: episode_000588.parquet
# Dropping observation.effort from: episode_000276.parquet
# Dropping observation.effort from: episode_000467.parquet
# Dropping observation.effort from: episode_000460.parquet
# Dropping observation.effort from: episode_000592.parquet
# Dropping observation.effort from: episode_000589.parquet
# Dropping observation.effort from: episode_000624.parquet
# Dropping observation.effort from: episode_000429.parquet
# Dropping observation.effort from: episode_000305.parquet
# Dropping observation.effort from: episode_000272.parquet
# Dropping observation.effort from: episode_000607.parquet
# Dropping observation.effort from: episode_000422.parquet
# Dropping observation.effort from: episode_000400.parquet
# Dropping observation.effort from: episode_000144.parquet
# Dropping observation.effort from: episode_000623.parquet
# Dropping observation.effort from: episode_000468.parquet
# Dropping observation.effort from: episode_000134.parquet
# Dropping observation.effort from: episode_000393.parquet
# Dropping observation.effort from: episode_000126.parquet
# Dropping observation.effort from: episode_000405.parquet
# Dropping observation.effort from: episode_000488.parquet
# Dropping observation.effort from: episode_000476.parquet
# Dropping observation.effort from: episode_000251.parquet
# Dropping observation.effort from: episode_000625.parquet
# Dropping observation.effort from: episode_000191.parquet
# Dropping observation.effort from: episode_000130.parquet
# Dropping observation.effort from: episode_000590.parquet
# Dropping observation.effort from: episode_000316.parquet
# Dropping observation.effort from: episode_000474.parquet
# Dropping observation.effort from: episode_000441.parquet
# Dropping observation.effort from: episode_000412.parquet
# Dropping observation.effort from: episode_000290.parquet
# Dropping observation.effort from: episode_000532.parquet
# Dropping observation.effort from: episode_000332.parquet
# Dropping observation.effort from: episode_000454.parquet
# Dropping observation.effort from: episode_000175.parquet
# Dropping observation.effort from: episode_000139.parquet
# Dropping observation.effort from: episode_000397.parquet
# Dropping observation.effort from: episode_000434.parquet
# Dropping observation.effort from: episode_000520.parquet
# Dropping observation.effort from: episode_000528.parquet
# Dropping observation.effort from: episode_000190.parquet
# Dropping observation.effort from: episode_000612.parquet
# Dropping observation.effort from: episode_000187.parquet
# Dropping observation.effort from: episode_000268.parquet
# Dropping observation.effort from: episode_000591.parquet
# Dropping observation.effort from: episode_000327.parquet
# Dropping observation.effort from: episode_000495.parquet
# Dropping observation.effort from: episode_000119.parquet
# Dropping observation.effort from: episode_000635.parquet
# Dropping observation.effort from: episode_000550.parquet
# Dropping observation.effort from: episode_000484.parquet
# Dropping observation.effort from: episode_000193.parquet
# Dropping observation.effort from: episode_000473.parquet
# Dropping observation.effort from: episode_000141.parquet
# Dropping observation.effort from: episode_000536.parquet
# Dropping observation.effort from: episode_000599.parquet
# Dropping observation.effort from: episode_000285.parquet
# Dropping observation.effort from: episode_000561.parquet
# Dropping observation.effort from: episode_000158.parquet
# Dropping observation.effort from: episode_000555.parquet
# Dropping observation.effort from: episode_000183.parquet
# Dropping observation.effort from: episode_000487.parquet
# Dropping observation.effort from: episode_000309.parquet
# Dropping observation.effort from: episode_000537.parquet
# Dropping observation.effort from: episode_000424.parquet
# Dropping observation.effort from: episode_000610.parquet
# Dropping observation.effort from: episode_000123.parquet
# Dropping observation.effort from: episode_000456.parquet
# Dropping observation.effort from: episode_000450.parquet
# Dropping observation.effort from: episode_000517.parquet
# Dropping observation.effort from: episode_000273.parquet
# Dropping observation.effort from: episode_000318.parquet
# Dropping observation.effort from: episode_000299.parquet
# Dropping observation.effort from: episode_000605.parquet
# Dropping observation.effort from: episode_000557.parquet
# Dropping observation.effort from: episode_000512.parquet
# Dropping observation.effort from: episode_000569.parquet
# Dropping observation.effort from: episode_000471.parquet
# Dropping observation.effort from: episode_000391.parquet
# Dropping observation.effort from: episode_000562.parquet
# Dropping observation.effort from: episode_000283.parquet
# Dropping observation.effort from: episode_000402.parquet
# Dropping observation.effort from: episode_000604.parquet
# Dropping observation.effort from: episode_000533.parquet
# Dropping observation.effort from: episode_000115.parquet
# Dropping observation.effort from: episode_000199.parquet
# Dropping observation.effort from: episode_000531.parquet
# Dropping observation.effort from: episode_000606.parquet
# Dropping observation.effort from: episode_000626.parquet
# Dropping observation.effort from: episode_000444.parquet
# Dropping observation.effort from: episode_000171.parquet
# Dropping observation.effort from: episode_000297.parquet
# Dropping observation.effort from: episode_000324.parquet
# Dropping observation.effort from: episode_000521.parquet
# Dropping observation.effort from: episode_000296.parquet
# Dropping observation.effort from: episode_000403.parquet
# Dropping observation.effort from: episode_000540.parquet
# Dropping observation.effort from: episode_000292.parquet
# Dropping observation.effort from: episode_000315.parquet
# Dropping observation.effort from: episode_000155.parquet
# Dropping observation.effort from: episode_000263.parquet
# Dropping observation.effort from: episode_000437.parquet
# Dropping observation.effort from: episode_000197.parquet
# Dropping observation.effort from: episode_000146.parquet
# Dropping observation.effort from: episode_000294.parquet
# Dropping observation.effort from: episode_000170.parquet
# Dropping observation.effort from: episode_000194.parquet
# Dropping observation.effort from: episode_000168.parquet
# Dropping observation.effort from: episode_000258.parquet
# Dropping observation.effort from: episode_000147.parquet
# Dropping observation.effort from: episode_000257.parquet
# Dropping observation.effort from: episode_000135.parquet
# Dropping observation.effort from: episode_000440.parquet
# Dropping observation.effort from: episode_000160.parquet
# Dropping observation.effort from: episode_000104.parquet
# Dropping observation.effort from: episode_000511.parquet
# Dropping observation.effort from: episode_000416.parquet
# Dropping observation.effort from: episode_000253.parquet
# Dropping observation.effort from: episode_000181.parquet
# Dropping observation.effort from: episode_000539.parquet
# Dropping observation.effort from: episode_000105.parquet
# Dropping observation.effort from: episode_000417.parquet
# Dropping observation.effort from: episode_000122.parquet
# Dropping observation.effort from: episode_000620.parquet
# Dropping observation.effort from: episode_000310.parquet
# Dropping observation.effort from: episode_000548.parquet
# Dropping observation.effort from: episode_000574.parquet
# Dropping observation.effort from: episode_000576.parquet
# Dropping observation.effort from: episode_000564.parquet
# Dropping observation.effort from: episode_000505.parquet
# Dropping observation.effort from: episode_000165.parquet
# Dropping observation.effort from: episode_000411.parquet
# Dropping observation.effort from: episode_000298.parquet
# Dropping observation.effort from: episode_000145.parquet
# Dropping observation.effort from: episode_000129.parquet
# Dropping observation.effort from: episode_000595.parquet
# Dropping observation.effort from: episode_000586.parquet
# Dropping observation.effort from: episode_000499.parquet
# Dropping observation.effort from: episode_000449.parquet
# Dropping observation.effort from: episode_000282.parquet
# Dropping observation.effort from: episode_000566.parquet
# Dropping observation.effort from: episode_000300.parquet
# Dropping observation.effort from: episode_000149.parquet
# Dropping observation.effort from: episode_000317.parquet
# Dropping observation.effort from: episode_000514.parquet
# Dropping observation.effort from: episode_000580.parquet
# Dropping observation.effort from: episode_000116.parquet
# Dropping observation.effort from: episode_000148.parquet
# Dropping observation.effort from: episode_000114.parquet
# Dropping observation.effort from: episode_000410.parquet
# Dropping observation.effort from: episode_000621.parquet
# Dropping observation.effort from: episode_000558.parquet
# Dropping observation.effort from: episode_000291.parquet
# Dropping observation.effort from: episode_000418.parquet
# Dropping observation.effort from: episode_000312.parquet
# Dropping observation.effort from: episode_000255.parquet
# Dropping observation.effort from: episode_000502.parquet
# Dropping observation.effort from: episode_000143.parquet
# Dropping observation.effort from: episode_000570.parquet
# Dropping observation.effort from: episode_000101.parquet
# Dropping observation.effort from: episode_000185.parquet
# Dropping observation.effort from: episode_000508.parquet
# Dropping observation.effort from: episode_000256.parquet
# Dropping observation.effort from: episode_000323.parquet
# Dropping observation.effort from: episode_000176.parquet
# Dropping observation.effort from: episode_000446.parquet
# Dropping observation.effort from: episode_000552.parquet
# Dropping observation.effort from: episode_000563.parquet
# Dropping observation.effort from: episode_000425.parquet
# Dropping observation.effort from: episode_000111.parquet
# Dropping observation.effort from: episode_000556.parquet
# Dropping observation.effort from: episode_000142.parquet
# Dropping observation.effort from: episode_000575.parquet
# Dropping observation.effort from: episode_000121.parquet
# Dropping observation.effort from: episode_000622.parquet
# Dropping observation.effort from: episode_000515.parquet
# Dropping observation.effort from: episode_000275.parquet
# Dropping observation.effort from: episode_000414.parquet
# Dropping observation.effort from: episode_000526.parquet
# Dropping observation.effort from: episode_000137.parquet
# Dropping observation.effort from: episode_000152.parquet
# Dropping observation.effort from: episode_000504.parquet
# Dropping observation.effort from: episode_000250.parquet
# Dropping observation.effort from: episode_000325.parquet
# Dropping observation.effort from: episode_000482.parquet
# Dropping observation.effort from: episode_000413.parquet
# Dropping observation.effort from: episode_000507.parquet
# Dropping observation.effort from: episode_000463.parquet
# Dropping observation.effort from: episode_000551.parquet
# Dropping observation.effort from: episode_000565.parquet
# Dropping observation.effort from: episode_000458.parquet
# Dropping observation.effort from: episode_000301.parquet
# Dropping observation.effort from: episode_000629.parquet
# Dropping observation.effort from: episode_000611.parquet
# Dropping observation.effort from: episode_000554.parquet
# Dropping observation.effort from: episode_000633.parquet
# Dropping observation.effort from: episode_000549.parquet
# Dropping observation.effort from: episode_000198.parquet
# Dropping observation.effort from: episode_000480.parquet
# Dropping observation.effort from: episode_000459.parquet
# Dropping observation.effort from: episode_000408.parquet
# Dropping observation.effort from: episode_000462.parquet
# Dropping observation.effort from: episode_000307.parquet
# Dropping observation.effort from: episode_000593.parquet
# Dropping observation.effort from: episode_000447.parquet
# Dropping observation.effort from: episode_000401.parquet
# Dropping observation.effort from: episode_000582.parquet
# Dropping observation.effort from: episode_000320.parquet
# Dropping observation.effort from: episode_000319.parquet
# Dropping observation.effort from: episode_000457.parquet
# Dropping observation.effort from: episode_000542.parquet
# Dropping observation.effort from: episode_000399.parquet
# Dropping observation.effort from: episode_000461.parquet
# Dropping observation.effort from: episode_000510.parquet
# Dropping observation.effort from: episode_000131.parquet
# Dropping observation.effort from: episode_000270.parquet
# Dropping observation.effort from: episode_000167.parquet
# Dropping observation.effort from: episode_000280.parquet
# Dropping observation.effort from: episode_000530.parquet
# Dropping observation.effort from: episode_000546.parquet
# Dropping observation.effort from: episode_000513.parquet
# Dropping observation.effort from: episode_000578.parquet
# Dropping observation.effort from: episode_000617.parquet
# Dropping observation.effort from: episode_000261.parquet
# Dropping observation.effort from: episode_000627.parquet
# Dropping observation.effort from: episode_000602.parquet
# Dropping observation.effort from: episode_000479.parquet

# %%
import os
import pandas as pd

dir_path = '/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain/data/chunk-000'
expected = set([
    'action',
    'observation.state',
    'timestamp',
    'frame_index',
    'episode_index',
    'index',
    'task_index'
])

for fname in os.listdir(dir_path):
    if fname.endswith('.parquet'):
        fpath = os.path.join(dir_path, fname)
        df = pd.read_parquet(fpath)
        extra = set(df.columns) - expected
        missing = expected - set(df.columns)
        if extra:
            print(f"{fname} has extra columns: {extra}")
        if missing:
            print(f"{fname} is missing columns: {missing}")
# Out:
# episode_000587.parquet has extra columns: {'observation.effort'}
# episode_000535.parquet has extra columns: {'observation.effort'}
# episode_000265.parquet has extra columns: {'observation.effort'}
# episode_000430.parquet has extra columns: {'observation.effort'}
# episode_000195.parquet has extra columns: {'observation.effort'}
# episode_000173.parquet has extra columns: {'observation.effort'}
# episode_000271.parquet has extra columns: {'observation.effort'}
# episode_000435.parquet has extra columns: {'observation.effort'}
# episode_000486.parquet has extra columns: {'observation.effort'}
# episode_000124.parquet has extra columns: {'observation.effort'}
# episode_000506.parquet has extra columns: {'observation.effort'}
# episode_000406.parquet has extra columns: {'observation.effort'}
# episode_000494.parquet has extra columns: {'observation.effort'}
# episode_000132.parquet has extra columns: {'observation.effort'}
# episode_000321.parquet has extra columns: {'observation.effort'}
# episode_000442.parquet has extra columns: {'observation.effort'}
# episode_000543.parquet has extra columns: {'observation.effort'}
# episode_000162.parquet has extra columns: {'observation.effort'}
# episode_000156.parquet has extra columns: {'observation.effort'}
# episode_000125.parquet has extra columns: {'observation.effort'}
# episode_000304.parquet has extra columns: {'observation.effort'}
# episode_000615.parquet has extra columns: {'observation.effort'}
# episode_000483.parquet has extra columns: {'observation.effort'}
# episode_000541.parquet has extra columns: {'observation.effort'}
# episode_000120.parquet has extra columns: {'observation.effort'}
# episode_000518.parquet has extra columns: {'observation.effort'}
# episode_000618.parquet has extra columns: {'observation.effort'}
# episode_000326.parquet has extra columns: {'observation.effort'}
# episode_000613.parquet has extra columns: {'observation.effort'}
# episode_000490.parquet has extra columns: {'observation.effort'}
# episode_000452.parquet has extra columns: {'observation.effort'}
# episode_000585.parquet has extra columns: {'observation.effort'}
# episode_000544.parquet has extra columns: {'observation.effort'}
# episode_000509.parquet has extra columns: {'observation.effort'}
# episode_000559.parquet has extra columns: {'observation.effort'}
# episode_000284.parquet has extra columns: {'observation.effort'}
# episode_000498.parquet has extra columns: {'observation.effort'}
# episode_000524.parquet has extra columns: {'observation.effort'}
# episode_000438.parquet has extra columns: {'observation.effort'}
# episode_000274.parquet has extra columns: {'observation.effort'}
# episode_000420.parquet has extra columns: {'observation.effort'}
# episode_000469.parquet has extra columns: {'observation.effort'}
# episode_000196.parquet has extra columns: {'observation.effort'}
# episode_000182.parquet has extra columns: {'observation.effort'}
# episode_000464.parquet has extra columns: {'observation.effort'}
# episode_000481.parquet has extra columns: {'observation.effort'}
# episode_000260.parquet has extra columns: {'observation.effort'}
# episode_000269.parquet has extra columns: {'observation.effort'}
# episode_000516.parquet has extra columns: {'observation.effort'}
# episode_000192.parquet has extra columns: {'observation.effort'}
# episode_000448.parquet has extra columns: {'observation.effort'}
# episode_000522.parquet has extra columns: {'observation.effort'}
# episode_000259.parquet has extra columns: {'observation.effort'}
# episode_000266.parquet has extra columns: {'observation.effort'}
# episode_000163.parquet has extra columns: {'observation.effort'}
# episode_000286.parquet has extra columns: {'observation.effort'}
# episode_000492.parquet has extra columns: {'observation.effort'}
# episode_000306.parquet has extra columns: {'observation.effort'}
# episode_000465.parquet has extra columns: {'observation.effort'}
# episode_000443.parquet has extra columns: {'observation.effort'}
# episode_000289.parquet has extra columns: {'observation.effort'}
# episode_000396.parquet has extra columns: {'observation.effort'}
# episode_000322.parquet has extra columns: {'observation.effort'}
# episode_000433.parquet has extra columns: {'observation.effort'}
# episode_000475.parquet has extra columns: {'observation.effort'}
# episode_000328.parquet has extra columns: {'observation.effort'}
# episode_000478.parquet has extra columns: {'observation.effort'}
# episode_000311.parquet has extra columns: {'observation.effort'}
# episode_000409.parquet has extra columns: {'observation.effort'}
# episode_000597.parquet has extra columns: {'observation.effort'}
# episode_000188.parquet has extra columns: {'observation.effort'}
# episode_000186.parquet has extra columns: {'observation.effort'}
# episode_000579.parquet has extra columns: {'observation.effort'}
# episode_000427.parquet has extra columns: {'observation.effort'}
# episode_000189.parquet has extra columns: {'observation.effort'}
# episode_000596.parquet has extra columns: {'observation.effort'}
# episode_000288.parquet has extra columns: {'observation.effort'}
# episode_000584.parquet has extra columns: {'observation.effort'}
# episode_000386.parquet has extra columns: {'observation.effort'}
# episode_000109.parquet has extra columns: {'observation.effort'}
# episode_000154.parquet has extra columns: {'observation.effort'}
# episode_000314.parquet has extra columns: {'observation.effort'}
# episode_000500.parquet has extra columns: {'observation.effort'}
# episode_000157.parquet has extra columns: {'observation.effort'}
# episode_000445.parquet has extra columns: {'observation.effort'}
# episode_000388.parquet has extra columns: {'observation.effort'}
# episode_000573.parquet has extra columns: {'observation.effort'}
# episode_000634.parquet has extra columns: {'observation.effort'}
# episode_000262.parquet has extra columns: {'observation.effort'}
# episode_000102.parquet has extra columns: {'observation.effort'}
# episode_000118.parquet has extra columns: {'observation.effort'}
# episode_000470.parquet has extra columns: {'observation.effort'}
# episode_000136.parquet has extra columns: {'observation.effort'}
# episode_000100.parquet has extra columns: {'observation.effort'}
# episode_000267.parquet has extra columns: {'observation.effort'}
# episode_000472.parquet has extra columns: {'observation.effort'}
# episode_000110.parquet has extra columns: {'observation.effort'}
# episode_000525.parquet has extra columns: {'observation.effort'}
# episode_000178.parquet has extra columns: {'observation.effort'}
# episode_000631.parquet has extra columns: {'observation.effort'}
# episode_000423.parquet has extra columns: {'observation.effort'}
# episode_000547.parquet has extra columns: {'observation.effort'}
# episode_000404.parquet has extra columns: {'observation.effort'}
# episode_000174.parquet has extra columns: {'observation.effort'}
# episode_000334.parquet has extra columns: {'observation.effort'}
# episode_000392.parquet has extra columns: {'observation.effort'}
# episode_000293.parquet has extra columns: {'observation.effort'}
# episode_000133.parquet has extra columns: {'observation.effort'}
# episode_000493.parquet has extra columns: {'observation.effort'}
# episode_000568.parquet has extra columns: {'observation.effort'}
# episode_000523.parquet has extra columns: {'observation.effort'}
# episode_000415.parquet has extra columns: {'observation.effort'}
# episode_000577.parquet has extra columns: {'observation.effort'}
# episode_000128.parquet has extra columns: {'observation.effort'}
# episode_000113.parquet has extra columns: {'observation.effort'}
# episode_000583.parquet has extra columns: {'observation.effort'}
# episode_000313.parquet has extra columns: {'observation.effort'}
# episode_000419.parquet has extra columns: {'observation.effort'}
# episode_000560.parquet has extra columns: {'observation.effort'}
# episode_000581.parquet has extra columns: {'observation.effort'}
# episode_000153.parquet has extra columns: {'observation.effort'}
# episode_000287.parquet has extra columns: {'observation.effort'}
# episode_000177.parquet has extra columns: {'observation.effort'}
# episode_000491.parquet has extra columns: {'observation.effort'}
# episode_000166.parquet has extra columns: {'observation.effort'}
# episode_000603.parquet has extra columns: {'observation.effort'}
# episode_000455.parquet has extra columns: {'observation.effort'}
# episode_000151.parquet has extra columns: {'observation.effort'}
# episode_000385.parquet has extra columns: {'observation.effort'}
# episode_000106.parquet has extra columns: {'observation.effort'}
# episode_000107.parquet has extra columns: {'observation.effort'}
# episode_000180.parquet has extra columns: {'observation.effort'}
# episode_000594.parquet has extra columns: {'observation.effort'}
# episode_000281.parquet has extra columns: {'observation.effort'}
# episode_000421.parquet has extra columns: {'observation.effort'}
# episode_000278.parquet has extra columns: {'observation.effort'}
# episode_000571.parquet has extra columns: {'observation.effort'}
# episode_000169.parquet has extra columns: {'observation.effort'}
# episode_000117.parquet has extra columns: {'observation.effort'}
# episode_000277.parquet has extra columns: {'observation.effort'}
# episode_000601.parquet has extra columns: {'observation.effort'}
# episode_000389.parquet has extra columns: {'observation.effort'}
# episode_000140.parquet has extra columns: {'observation.effort'}
# episode_000264.parquet has extra columns: {'observation.effort'}
# episode_000295.parquet has extra columns: {'observation.effort'}
# episode_000395.parquet has extra columns: {'observation.effort'}
# episode_000161.parquet has extra columns: {'observation.effort'}
# episode_000489.parquet has extra columns: {'observation.effort'}
# episode_000428.parquet has extra columns: {'observation.effort'}
# episode_000630.parquet has extra columns: {'observation.effort'}
# episode_000538.parquet has extra columns: {'observation.effort'}
# episode_000407.parquet has extra columns: {'observation.effort'}
# episode_000496.parquet has extra columns: {'observation.effort'}
# episode_000477.parquet has extra columns: {'observation.effort'}
# episode_000394.parquet has extra columns: {'observation.effort'}
# episode_000600.parquet has extra columns: {'observation.effort'}
# episode_000150.parquet has extra columns: {'observation.effort'}
# episode_000534.parquet has extra columns: {'observation.effort'}
# episode_000572.parquet has extra columns: {'observation.effort'}
# episode_000398.parquet has extra columns: {'observation.effort'}
# episode_000628.parquet has extra columns: {'observation.effort'}
# episode_000439.parquet has extra columns: {'observation.effort'}
# episode_000308.parquet has extra columns: {'observation.effort'}
# episode_000497.parquet has extra columns: {'observation.effort'}
# episode_000279.parquet has extra columns: {'observation.effort'}
# episode_000331.parquet has extra columns: {'observation.effort'}
# episode_000254.parquet has extra columns: {'observation.effort'}
# episode_000164.parquet has extra columns: {'observation.effort'}
# episode_000333.parquet has extra columns: {'observation.effort'}
# episode_000616.parquet has extra columns: {'observation.effort'}
# episode_000112.parquet has extra columns: {'observation.effort'}
# episode_000179.parquet has extra columns: {'observation.effort'}
# episode_000527.parquet has extra columns: {'observation.effort'}
# episode_000608.parquet has extra columns: {'observation.effort'}
# episode_000453.parquet has extra columns: {'observation.effort'}
# episode_000614.parquet has extra columns: {'observation.effort'}
# episode_000303.parquet has extra columns: {'observation.effort'}
# episode_000329.parquet has extra columns: {'observation.effort'}
# episode_000632.parquet has extra columns: {'observation.effort'}
# episode_000330.parquet has extra columns: {'observation.effort'}
# episode_000184.parquet has extra columns: {'observation.effort'}
# episode_000501.parquet has extra columns: {'observation.effort'}
# episode_000619.parquet has extra columns: {'observation.effort'}
# episode_000103.parquet has extra columns: {'observation.effort'}
# episode_000172.parquet has extra columns: {'observation.effort'}
# episode_000138.parquet has extra columns: {'observation.effort'}
# episode_000390.parquet has extra columns: {'observation.effort'}
# episode_000436.parquet has extra columns: {'observation.effort'}
# episode_000609.parquet has extra columns: {'observation.effort'}
# episode_000426.parquet has extra columns: {'observation.effort'}
# episode_000598.parquet has extra columns: {'observation.effort'}
# episode_000451.parquet has extra columns: {'observation.effort'}
# episode_000431.parquet has extra columns: {'observation.effort'}
# episode_000553.parquet has extra columns: {'observation.effort'}
# episode_000485.parquet has extra columns: {'observation.effort'}
# episode_000252.parquet has extra columns: {'observation.effort'}
# episode_000302.parquet has extra columns: {'observation.effort'}
# episode_000432.parquet has extra columns: {'observation.effort'}
# episode_000529.parquet has extra columns: {'observation.effort'}
# episode_000127.parquet has extra columns: {'observation.effort'}
# episode_000108.parquet has extra columns: {'observation.effort'}
# episode_000567.parquet has extra columns: {'observation.effort'}
# episode_000159.parquet has extra columns: {'observation.effort'}
# episode_000519.parquet has extra columns: {'observation.effort'}
# episode_000466.parquet has extra columns: {'observation.effort'}
# episode_000503.parquet has extra columns: {'observation.effort'}
# episode_000387.parquet has extra columns: {'observation.effort'}
# episode_000545.parquet has extra columns: {'observation.effort'}
# episode_000588.parquet has extra columns: {'observation.effort'}
# episode_000276.parquet has extra columns: {'observation.effort'}
# episode_000467.parquet has extra columns: {'observation.effort'}
# episode_000460.parquet has extra columns: {'observation.effort'}
# episode_000592.parquet has extra columns: {'observation.effort'}
# episode_000589.parquet has extra columns: {'observation.effort'}
# episode_000624.parquet has extra columns: {'observation.effort'}
# episode_000429.parquet has extra columns: {'observation.effort'}
# episode_000305.parquet has extra columns: {'observation.effort'}
# episode_000272.parquet has extra columns: {'observation.effort'}
# episode_000607.parquet has extra columns: {'observation.effort'}
# episode_000422.parquet has extra columns: {'observation.effort'}
# episode_000400.parquet has extra columns: {'observation.effort'}
# episode_000144.parquet has extra columns: {'observation.effort'}
# episode_000623.parquet has extra columns: {'observation.effort'}
# episode_000468.parquet has extra columns: {'observation.effort'}
# episode_000134.parquet has extra columns: {'observation.effort'}
# episode_000393.parquet has extra columns: {'observation.effort'}
# episode_000126.parquet has extra columns: {'observation.effort'}
# episode_000405.parquet has extra columns: {'observation.effort'}
# episode_000488.parquet has extra columns: {'observation.effort'}
# episode_000476.parquet has extra columns: {'observation.effort'}
# episode_000251.parquet has extra columns: {'observation.effort'}
# episode_000625.parquet has extra columns: {'observation.effort'}
# episode_000191.parquet has extra columns: {'observation.effort'}
# episode_000130.parquet has extra columns: {'observation.effort'}
# episode_000590.parquet has extra columns: {'observation.effort'}
# episode_000316.parquet has extra columns: {'observation.effort'}
# episode_000474.parquet has extra columns: {'observation.effort'}
# episode_000441.parquet has extra columns: {'observation.effort'}
# episode_000412.parquet has extra columns: {'observation.effort'}
# episode_000290.parquet has extra columns: {'observation.effort'}
# episode_000532.parquet has extra columns: {'observation.effort'}
# episode_000332.parquet has extra columns: {'observation.effort'}
# episode_000454.parquet has extra columns: {'observation.effort'}
# episode_000175.parquet has extra columns: {'observation.effort'}
# episode_000139.parquet has extra columns: {'observation.effort'}
# episode_000397.parquet has extra columns: {'observation.effort'}
# episode_000434.parquet has extra columns: {'observation.effort'}
# episode_000520.parquet has extra columns: {'observation.effort'}
# episode_000528.parquet has extra columns: {'observation.effort'}
# episode_000190.parquet has extra columns: {'observation.effort'}
# episode_000612.parquet has extra columns: {'observation.effort'}
# episode_000187.parquet has extra columns: {'observation.effort'}
# episode_000268.parquet has extra columns: {'observation.effort'}
# episode_000591.parquet has extra columns: {'observation.effort'}
# episode_000327.parquet has extra columns: {'observation.effort'}
# episode_000495.parquet has extra columns: {'observation.effort'}
# episode_000119.parquet has extra columns: {'observation.effort'}
# episode_000635.parquet has extra columns: {'observation.effort'}
# episode_000550.parquet has extra columns: {'observation.effort'}
# episode_000484.parquet has extra columns: {'observation.effort'}
# episode_000193.parquet has extra columns: {'observation.effort'}
# episode_000473.parquet has extra columns: {'observation.effort'}
# episode_000141.parquet has extra columns: {'observation.effort'}
# episode_000536.parquet has extra columns: {'observation.effort'}
# episode_000599.parquet has extra columns: {'observation.effort'}
# episode_000285.parquet has extra columns: {'observation.effort'}
# episode_000561.parquet has extra columns: {'observation.effort'}
# episode_000158.parquet has extra columns: {'observation.effort'}
# episode_000555.parquet has extra columns: {'observation.effort'}
# episode_000183.parquet has extra columns: {'observation.effort'}
# episode_000487.parquet has extra columns: {'observation.effort'}
# episode_000309.parquet has extra columns: {'observation.effort'}
# episode_000537.parquet has extra columns: {'observation.effort'}
# episode_000424.parquet has extra columns: {'observation.effort'}
# episode_000610.parquet has extra columns: {'observation.effort'}
# episode_000123.parquet has extra columns: {'observation.effort'}
# episode_000456.parquet has extra columns: {'observation.effort'}
# episode_000450.parquet has extra columns: {'observation.effort'}
# episode_000517.parquet has extra columns: {'observation.effort'}
# episode_000273.parquet has extra columns: {'observation.effort'}
# episode_000318.parquet has extra columns: {'observation.effort'}
# episode_000299.parquet has extra columns: {'observation.effort'}
# episode_000605.parquet has extra columns: {'observation.effort'}
# episode_000557.parquet has extra columns: {'observation.effort'}
# episode_000512.parquet has extra columns: {'observation.effort'}
# episode_000569.parquet has extra columns: {'observation.effort'}
# episode_000471.parquet has extra columns: {'observation.effort'}
# episode_000391.parquet has extra columns: {'observation.effort'}
# episode_000562.parquet has extra columns: {'observation.effort'}
# episode_000283.parquet has extra columns: {'observation.effort'}
# episode_000402.parquet has extra columns: {'observation.effort'}
# episode_000604.parquet has extra columns: {'observation.effort'}
# episode_000533.parquet has extra columns: {'observation.effort'}
# episode_000115.parquet has extra columns: {'observation.effort'}
# episode_000199.parquet has extra columns: {'observation.effort'}
# episode_000531.parquet has extra columns: {'observation.effort'}
# episode_000606.parquet has extra columns: {'observation.effort'}
# episode_000626.parquet has extra columns: {'observation.effort'}
# episode_000444.parquet has extra columns: {'observation.effort'}
# episode_000171.parquet has extra columns: {'observation.effort'}
# episode_000297.parquet has extra columns: {'observation.effort'}
# episode_000324.parquet has extra columns: {'observation.effort'}
# episode_000521.parquet has extra columns: {'observation.effort'}
# episode_000296.parquet has extra columns: {'observation.effort'}
# episode_000403.parquet has extra columns: {'observation.effort'}
# episode_000540.parquet has extra columns: {'observation.effort'}
# episode_000292.parquet has extra columns: {'observation.effort'}
# episode_000315.parquet has extra columns: {'observation.effort'}
# episode_000155.parquet has extra columns: {'observation.effort'}
# episode_000263.parquet has extra columns: {'observation.effort'}
# episode_000437.parquet has extra columns: {'observation.effort'}
# episode_000197.parquet has extra columns: {'observation.effort'}
# episode_000146.parquet has extra columns: {'observation.effort'}
# episode_000294.parquet has extra columns: {'observation.effort'}
# episode_000170.parquet has extra columns: {'observation.effort'}
# episode_000194.parquet has extra columns: {'observation.effort'}
# episode_000168.parquet has extra columns: {'observation.effort'}
# episode_000258.parquet has extra columns: {'observation.effort'}
# episode_000147.parquet has extra columns: {'observation.effort'}
# episode_000257.parquet has extra columns: {'observation.effort'}
# episode_000135.parquet has extra columns: {'observation.effort'}
# episode_000440.parquet has extra columns: {'observation.effort'}
# episode_000160.parquet has extra columns: {'observation.effort'}
# episode_000104.parquet has extra columns: {'observation.effort'}
# episode_000511.parquet has extra columns: {'observation.effort'}
# episode_000416.parquet has extra columns: {'observation.effort'}
# episode_000253.parquet has extra columns: {'observation.effort'}
# episode_000181.parquet has extra columns: {'observation.effort'}
# episode_000539.parquet has extra columns: {'observation.effort'}
# episode_000105.parquet has extra columns: {'observation.effort'}
# episode_000417.parquet has extra columns: {'observation.effort'}
# episode_000122.parquet has extra columns: {'observation.effort'}
# episode_000620.parquet has extra columns: {'observation.effort'}
# episode_000310.parquet has extra columns: {'observation.effort'}
# episode_000548.parquet has extra columns: {'observation.effort'}
# episode_000574.parquet has extra columns: {'observation.effort'}
# episode_000576.parquet has extra columns: {'observation.effort'}
# episode_000564.parquet has extra columns: {'observation.effort'}
# episode_000505.parquet has extra columns: {'observation.effort'}
# episode_000165.parquet has extra columns: {'observation.effort'}
# episode_000411.parquet has extra columns: {'observation.effort'}
# episode_000298.parquet has extra columns: {'observation.effort'}
# episode_000145.parquet has extra columns: {'observation.effort'}
# episode_000129.parquet has extra columns: {'observation.effort'}
# episode_000595.parquet has extra columns: {'observation.effort'}
# episode_000586.parquet has extra columns: {'observation.effort'}
# episode_000499.parquet has extra columns: {'observation.effort'}
# episode_000449.parquet has extra columns: {'observation.effort'}
# episode_000282.parquet has extra columns: {'observation.effort'}
# episode_000566.parquet has extra columns: {'observation.effort'}
# episode_000300.parquet has extra columns: {'observation.effort'}
# episode_000149.parquet has extra columns: {'observation.effort'}
# episode_000317.parquet has extra columns: {'observation.effort'}
# episode_000514.parquet has extra columns: {'observation.effort'}
# episode_000580.parquet has extra columns: {'observation.effort'}
# episode_000116.parquet has extra columns: {'observation.effort'}
# episode_000148.parquet has extra columns: {'observation.effort'}
# episode_000114.parquet has extra columns: {'observation.effort'}
# episode_000410.parquet has extra columns: {'observation.effort'}
# episode_000621.parquet has extra columns: {'observation.effort'}
# episode_000558.parquet has extra columns: {'observation.effort'}
# episode_000291.parquet has extra columns: {'observation.effort'}
# episode_000418.parquet has extra columns: {'observation.effort'}
# episode_000312.parquet has extra columns: {'observation.effort'}
# episode_000255.parquet has extra columns: {'observation.effort'}
# episode_000502.parquet has extra columns: {'observation.effort'}
# episode_000143.parquet has extra columns: {'observation.effort'}
# episode_000570.parquet has extra columns: {'observation.effort'}
# episode_000101.parquet has extra columns: {'observation.effort'}
# episode_000185.parquet has extra columns: {'observation.effort'}
# episode_000508.parquet has extra columns: {'observation.effort'}
# episode_000256.parquet has extra columns: {'observation.effort'}
# episode_000323.parquet has extra columns: {'observation.effort'}
# episode_000176.parquet has extra columns: {'observation.effort'}
# episode_000446.parquet has extra columns: {'observation.effort'}
# episode_000552.parquet has extra columns: {'observation.effort'}
# episode_000563.parquet has extra columns: {'observation.effort'}
# episode_000425.parquet has extra columns: {'observation.effort'}
# episode_000111.parquet has extra columns: {'observation.effort'}
# episode_000556.parquet has extra columns: {'observation.effort'}
# episode_000142.parquet has extra columns: {'observation.effort'}
# episode_000575.parquet has extra columns: {'observation.effort'}
# episode_000121.parquet has extra columns: {'observation.effort'}
# episode_000622.parquet has extra columns: {'observation.effort'}
# episode_000515.parquet has extra columns: {'observation.effort'}
# episode_000275.parquet has extra columns: {'observation.effort'}
# episode_000414.parquet has extra columns: {'observation.effort'}
# episode_000526.parquet has extra columns: {'observation.effort'}
# episode_000137.parquet has extra columns: {'observation.effort'}
# episode_000152.parquet has extra columns: {'observation.effort'}
# episode_000504.parquet has extra columns: {'observation.effort'}
# episode_000250.parquet has extra columns: {'observation.effort'}
# episode_000325.parquet has extra columns: {'observation.effort'}
# episode_000482.parquet has extra columns: {'observation.effort'}
# episode_000413.parquet has extra columns: {'observation.effort'}
# episode_000507.parquet has extra columns: {'observation.effort'}
# episode_000463.parquet has extra columns: {'observation.effort'}
# episode_000551.parquet has extra columns: {'observation.effort'}
# episode_000565.parquet has extra columns: {'observation.effort'}
# episode_000458.parquet has extra columns: {'observation.effort'}
# episode_000301.parquet has extra columns: {'observation.effort'}
# episode_000629.parquet has extra columns: {'observation.effort'}
# episode_000611.parquet has extra columns: {'observation.effort'}
# episode_000554.parquet has extra columns: {'observation.effort'}
# episode_000633.parquet has extra columns: {'observation.effort'}
# episode_000549.parquet has extra columns: {'observation.effort'}
# episode_000198.parquet has extra columns: {'observation.effort'}
# episode_000480.parquet has extra columns: {'observation.effort'}
# episode_000459.parquet has extra columns: {'observation.effort'}
# episode_000408.parquet has extra columns: {'observation.effort'}
# episode_000462.parquet has extra columns: {'observation.effort'}
# episode_000307.parquet has extra columns: {'observation.effort'}
# episode_000593.parquet has extra columns: {'observation.effort'}
# episode_000447.parquet has extra columns: {'observation.effort'}
# episode_000401.parquet has extra columns: {'observation.effort'}
# episode_000582.parquet has extra columns: {'observation.effort'}
# episode_000320.parquet has extra columns: {'observation.effort'}
# episode_000319.parquet has extra columns: {'observation.effort'}
# episode_000457.parquet has extra columns: {'observation.effort'}
# episode_000542.parquet has extra columns: {'observation.effort'}
# episode_000399.parquet has extra columns: {'observation.effort'}
# episode_000461.parquet has extra columns: {'observation.effort'}
# episode_000510.parquet has extra columns: {'observation.effort'}
# episode_000131.parquet has extra columns: {'observation.effort'}
# episode_000270.parquet has extra columns: {'observation.effort'}
# episode_000167.parquet has extra columns: {'observation.effort'}
# episode_000280.parquet has extra columns: {'observation.effort'}
# episode_000530.parquet has extra columns: {'observation.effort'}
# episode_000546.parquet has extra columns: {'observation.effort'}
# episode_000513.parquet has extra columns: {'observation.effort'}
# episode_000578.parquet has extra columns: {'observation.effort'}
# episode_000617.parquet has extra columns: {'observation.effort'}
# episode_000261.parquet has extra columns: {'observation.effort'}
# episode_000627.parquet has extra columns: {'observation.effort'}
# episode_000602.parquet has extra columns: {'observation.effort'}
# episode_000479.parquet has extra columns: {'observation.effort'}

# %%
# !python lerobot/scripts/train.py \
  --dataset.repo_id=local \
  --dataset.root=/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain \
  --output_dir=outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain \
  --policy.type=act \
  --policy.device=cuda \
  --batch_size=8 \
  --steps=200000 \
  --save_freq=20000 \
  --wandb.enable=false \
  --policy.chunk_size=75 \
  --policy.n_action_steps=75 \
  --policy.n_encoder_layers=4 \
  --policy.n_decoder_layers=7 \
  --policy.dim_feedforward=3200 \
  --policy.dim_model=512 \
  --policy.n_heads=8 \
  --policy.dropout=0.1 \
  --optimizer.lr=1e-5 \
  --seed=1000
# Out:
# INFO 2025-05-22 14:50:33 ts/train.py:111 {'batch_size': 8,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'local',
#              'revision': None,
#              'root': '/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain',
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'act',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain',
#  'policy': {'chunk_size': 75,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'n_action_steps': 75,
#             'n_decoder_layers': 7,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'replace_final_stride_with_dilation': False,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 200000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': False,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# INFO 2025-05-22 14:50:33 ts/train.py:117 Logs will be saved locally.
# INFO 2025-05-22 14:50:33 ts/train.py:127 Creating dataset
# Resolving data files: 100%|████████████████| 692/692 [00:00<00:00, 52163.08it/s]
# Downloading data: 100%|█████████████████| 692/692 [00:00<00:00, 27980.09files/s]
# Generating train split: 407937 examples [00:00, 473675.56 examples/s]
# INFO 2025-05-22 14:50:39 ts/train.py:138 Creating policy
# INFO 2025-05-22 14:50:40 ts/train.py:152 Creating optimizer and scheduler
# INFO 2025-05-22 14:50:40 ts/train.py:164 Output dir: outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain
# INFO 2025-05-22 14:50:40 ts/train.py:167 cfg.steps=200000 (200K)
# INFO 2025-05-22 14:50:40 ts/train.py:168 dataset.num_frames=407937 (408K)
# INFO 2025-05-22 14:50:40 ts/train.py:169 dataset.num_episodes=692
# INFO 2025-05-22 14:50:40 ts/train.py:170 num_learnable_params=83916944 (84M)
# INFO 2025-05-22 14:50:40 ts/train.py:171 num_total_params=83917064 (84M)
# INFO 2025-05-22 14:50:40 ts/train.py:210 Start offline training on a fixed dataset
# INFO 2025-05-22 14:51:53 ts/train.py:240 step:200 smpl:2K ep:3 epch:0.00 loss:7.753 grdn:159.095 lr:1.0e-05 updt_s:0.363 data_s:0.004
# INFO 2025-05-22 14:53:05 ts/train.py:240 step:400 smpl:3K ep:5 epch:0.01 loss:3.108 grdn:85.302 lr:1.0e-05 updt_s:0.359 data_s:0.000
# INFO 2025-05-22 14:54:18 ts/train.py:240 step:600 smpl:5K ep:8 epch:0.01 loss:2.602 grdn:72.995 lr:1.0e-05 updt_s:0.362 data_s:0.000
# INFO 2025-05-22 14:55:31 ts/train.py:240 step:800 smpl:6K ep:11 epch:0.02 loss:2.320 grdn:69.503 lr:1.0e-05 updt_s:0.363 data_s:0.000
# INFO 2025-05-22 14:56:44 ts/train.py:240 step:1K smpl:8K ep:14 epch:0.02 loss:2.084 grdn:63.398 lr:1.0e-05 updt_s:0.364 data_s:0.000
# INFO 2025-05-22 14:57:57 ts/train.py:240 step:1K smpl:10K ep:16 epch:0.02 loss:1.899 grdn:60.485 lr:1.0e-05 updt_s:0.365 data_s:0.000
# INFO 2025-05-22 14:59:11 ts/train.py:240 step:1K smpl:11K ep:19 epch:0.03 loss:1.749 grdn:57.845 lr:1.0e-05 updt_s:0.368 data_s:0.000
# INFO 2025-05-22 15:00:26 ts/train.py:240 step:2K smpl:13K ep:22 epch:0.03 loss:1.606 grdn:54.871 lr:1.0e-05 updt_s:0.373 data_s:0.000
# INFO 2025-05-22 15:01:41 ts/train.py:240 step:2K smpl:14K ep:24 epch:0.04 loss:1.495 grdn:52.139 lr:1.0e-05 updt_s:0.373 data_s:0.000
# INFO 2025-05-22 15:02:56 ts/train.py:240 step:2K smpl:16K ep:27 epch:0.04 loss:1.361 grdn:49.321 lr:1.0e-05 updt_s:0.374 data_s:0.000
# INFO 2025-05-22 15:04:11 ts/train.py:240 step:2K smpl:18K ep:30 epch:0.04 loss:1.257 grdn:47.499 lr:1.0e-05 updt_s:0.377 data_s:0.000
# ^C
# Traceback (most recent call last):
#   File "/mnt/newssd/lerobot/lerobot/scripts/train.py", line 296, in <module>
#     train()
#   File "/mnt/newssd/lerobot/lerobot/configs/parser.py", line 227, in wrapper_inner
#     response = fn(cfg, *args, **kwargs)
#   File "/mnt/newssd/lerobot/lerobot/scripts/train.py", line 220, in train
#     train_tracker, output_dict = update_policy(
#   File "/mnt/newssd/lerobot/lerobot/scripts/train.py", line 101, in update_policy
#     train_metrics.loss = loss.item()
# KeyboardInterrupt

# %%
# !python lerobot/scripts/cotrain.py \
  --dataset.repo_id=local \
  --dataset.root=/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain \
  --output_dir=outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain_692data \
  --policy.type=act \
  --policy.device=cuda \
  --batch_size=8 \
  --job_name=act_692_cotrain\
  --steps=400000 \
  --save_freq=20000 \
  --wandb.enable=true \
  --policy.chunk_size=75 \
  --policy.n_action_steps=75 \
  --policy.n_encoder_layers=4 \
  --policy.n_decoder_layers=7 \
  --policy.dim_feedforward=3200 \
  --policy.dim_model=512 \
  --policy.n_heads=8 \
  --policy.dropout=0.1 \
  --optimizer.lr=1e-5 \
  --seed=1000
# Out:
# INFO 2025-05-22 15:25:05 /cotrain.py:112 {'batch_size': 8,
#  'dataset': {'episodes': None,
#              'image_transforms': {'enable': False,
#                                   'max_num_transforms': 3,
#                                   'random_order': False,
#                                   'tfs': {'brightness': {'kwargs': {'brightness': [0.8,
#                                                                                    1.2]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'contrast': {'kwargs': {'contrast': [0.8,
#                                                                                1.2]},
#                                                        'type': 'ColorJitter',
#                                                        'weight': 1.0},
#                                           'hue': {'kwargs': {'hue': [-0.05,
#                                                                      0.05]},
#                                                   'type': 'ColorJitter',
#                                                   'weight': 1.0},
#                                           'saturation': {'kwargs': {'saturation': [0.5,
#                                                                                    1.5]},
#                                                          'type': 'ColorJitter',
#                                                          'weight': 1.0},
#                                           'sharpness': {'kwargs': {'sharpness': [0.5,
#                                                                                  1.5]},
#                                                         'type': 'SharpnessJitter',
#                                                         'weight': 1.0}}},
#              'repo_id': 'local',
#              'revision': None,
#              'root': '/mnt/newssd/lerobot/lerobot/datasets/Task_PicupBrick_50fps_with_mountingpoints_cotrain',
#              'use_imagenet_stats': True,
#              'video_backend': 'torchcodec'},
#  'env': None,
#  'eval': {'batch_size': 50, 'n_episodes': 50, 'use_async_envs': False},
#  'eval_freq': 20000,
#  'job_name': 'act_692_cotrain',
#  'log_freq': 200,
#  'num_workers': 4,
#  'optimizer': {'betas': [0.9, 0.999],
#                'eps': 1e-08,
#                'grad_clip_norm': 10.0,
#                'lr': 1e-05,
#                'type': 'adamw',
#                'weight_decay': 0.0001},
#  'output_dir': 'outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain_692data',
#  'policy': {'chunk_size': 75,
#             'device': 'cuda',
#             'dim_feedforward': 3200,
#             'dim_model': 512,
#             'dropout': 0.1,
#             'feedforward_activation': 'relu',
#             'input_features': {},
#             'kl_weight': 10.0,
#             'latent_dim': 32,
#             'n_action_steps': 75,
#             'n_decoder_layers': 7,
#             'n_encoder_layers': 4,
#             'n_heads': 8,
#             'n_obs_steps': 1,
#             'n_vae_encoder_layers': 4,
#             'normalization_mapping': {'ACTION': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'STATE': <NormalizationMode.MEAN_STD: 'MEAN_STD'>,
#                                       'VISUAL': <NormalizationMode.MEAN_STD: 'MEAN_STD'>},
#             'optimizer_lr': 1e-05,
#             'optimizer_lr_backbone': 1e-05,
#             'optimizer_weight_decay': 0.0001,
#             'output_features': {},
#             'pre_norm': False,
#             'pretrained_backbone_weights': 'ResNet18_Weights.IMAGENET1K_V1',
#             'replace_final_stride_with_dilation': False,
#             'temporal_ensemble_coeff': None,
#             'type': 'act',
#             'use_amp': False,
#             'use_vae': True,
#             'vision_backbone': 'resnet18'},
#  'resume': False,
#  'save_checkpoint': True,
#  'save_freq': 20000,
#  'scheduler': None,
#  'seed': 1000,
#  'steps': 400000,
#  'use_policy_training_preset': True,
#  'wandb': {'disable_artifact': False,
#            'enable': True,
#            'entity': None,
#            'mode': None,
#            'notes': None,
#            'project': 'lerobot',
#            'run_id': None}}
# Logs will be synced with wandb.
# INFO 2025-05-22 15:25:06 ndb_utils.py:96 Track this run --> https://wandb.ai/huyue/lerobot/runs/mqzr222a
# INFO 2025-05-22 15:25:06 /cotrain.py:128 Creating dataset
# Resolving data files: 100%|████████████████| 692/692 [00:00<00:00, 44040.03it/s]
# INFO 2025-05-22 15:25:11 /cotrain.py:139 Creating policy
# INFO 2025-05-22 15:25:12 /cotrain.py:153 Creating optimizer and scheduler
# INFO 2025-05-22 15:25:12 /cotrain.py:165 Output dir: outputs/train/act_Task_PicupBrick_50fps_with_mountingpoints_cotrain_692data
# INFO 2025-05-22 15:25:12 /cotrain.py:168 cfg.steps=400000 (400K)
# INFO 2025-05-22 15:25:12 /cotrain.py:169 dataset.num_frames=407937 (408K)
# INFO 2025-05-22 15:25:12 /cotrain.py:170 dataset.num_episodes=692
# INFO 2025-05-22 15:25:12 /cotrain.py:171 num_learnable_params=83916944 (84M)
# INFO 2025-05-22 15:25:12 /cotrain.py:172 num_total_params=83917064 (84M)
# INFO 2025-05-22 15:25:12 /cotrain.py:205 Start offline training on a fixed dataset
# INFO 2025-05-22 15:26:27 /cotrain.py:244 step:200 smpl:2K ep:3 epch:0.00 loss:7.515 grdn:154.817 lr:1.0e-05 updt_s:0.366 data_s:0.005
